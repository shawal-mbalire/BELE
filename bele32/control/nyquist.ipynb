# %%
# %pip install control slycot --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 1.6 MB/s eta 0:00:0000:0100:010m
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 598.3 kB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.1/455.1 kB 2.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 4.5 MB/s eta 0:00:0000:0100:01
# ...
#   Created wheel for slycot: filename=slycot-0.5.4-cp311-cp311-linux_x86_64.whl size=2185603 sha256=2a49bedae59c404836633d45dcb6d00575c4769afbaa43c4f3a4d89d95acfb64
#   Stored in directory: /home/shawal/.cache/pip/wheels/d3/b6/2c/9f852652c355430bc20e661d594d4a829d4467e17df7d13983
# Successfully built slycot
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import control as ct

# %%
sys = ct.ss(A, B, C, D)

# %%
num = [1]
den = [1,2, 1]
sys = ct.tf(num, den)
sys
# Out:
# TransferFunction(array([1]), array([1, 2, 1]))

# %%
G = ct.zpk([], [-1, -2, -3], gain=100)
ct.nyquist_plot(G)
# Out:
# 2
